# %% [markdown]
# # Girona Kale distribution
#
# A new company looks for potential buyers (restautants and supermarkets) for a new and healthy product. The production and process plant will be placed in some
# place arround Catalunya. The principals objectives are:
#
# + Look the best location for the company
# + Look for the best place for an office in the selected area (city)
# + List for a potencial buyers (Restaurants and supermarkets)

# %% [markdown]
# ## Climate areas, to select the best province
#
# In Catalonia, Spain,there are 4 big areas ("provincias"), we can compare the climate of each one by scraping the data of diferent web pages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ### Tempreature for Barcelona

# %%
#Import the url

url = "https://es.wikipedia.org/wiki/Barcelona"
html = urlopen(url)

soup = BeautifulSoup(html, 'lxml')
type(soup)

# %%
#Get the rows of the data table
rows = soup.find_all('tr')

import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)

df = pd.DataFrame(list_rows)

#Select our interest rows
df = df.iloc[40:47,]

df[0] = df[0].str.strip('[ ] \n')

df = df[0].str.split(',', expand=True)

for i in range (0,13):
    df[i] = df[i].str.strip('\n')
    
df['Tempreature'] = 'Mean T Barcelona'
    
df.rename(columns={ 0 : "J", 1 :'F', 2 :'M', 3 :'A', 4 :'My', 5 :'J', 6 :'Jl', 7 :'Ag', 8 :'S', 9 :'O', 10 :'N', 11 :'D', 12 :'ANUAL', }, inplace=True)

dfB = df.iloc[5:6,]

# %%
dfB.head(10)
# Out:
#        J      F      M      A     My      J     Jl     Ag      S      O  \
# 45  11.8   12.4   14.2   15.8   19.3   23.0   25.7   26.1   23.0   19.5
#
#         N      D  ANUAL       Tempreature
# 45   14.9   12.3   18.2  Mean T Barcelona

# %% [markdown]
# ### Temperature for Girona

# %%
#Import the url

url = "https://es.wikipedia.org/wiki/Gerona"
html = urlopen(url)

soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#Get the rows of the data table
rows = soup.find_all('tr')

import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)

df = pd.DataFrame(list_rows)

#Select our interest rows
df = df.iloc[30:37,]

df[0] = df[0].str.strip('[ ] \n')

df = df[0].str.split(',', expand=True)

for i in range (0,13):
    df[i] = df[i].str.strip('\n')
    
df['Tempreature'] = 'Mean T Girona'
    
df.rename(columns={ 0 : "J", 1 :'F', 2 :'M', 3 :'A', 4 :'My', 5 :'J', 6 :'Jl', 7 :'Ag', 8 :'S', 9 :'O', 10 :'N', 11 :'D', 12 :'ANUAL', }, inplace=True)

dfG = df.iloc[6:7,]

# %%
dfG.head()
# Out:
#       J     F      M      A     My      J     Jl     Ag      S      O      N  \
# 36  7.1   7.9   10.4   12.5   16.3   20.4   23.6   23.4   20.1   16.2   10.9
#
#        D  ANUAL    Tempreature
# 36   7.8   14.7  Mean T Girona

# %% [markdown]
# ## Tempreature Tarragona

# %%
#Import the url

url = "https://es.wikipedia.org/wiki/Tarragona"
html = urlopen(url)

soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#Get the rows of the data table
rows = soup.find_all('tr')

import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)

df = pd.DataFrame(list_rows)

#Select our interest rows
df = df.iloc[30:37,]

df[0] = df[0].str.strip('[ ] \n')

df = df[0].str.split(',', expand=True)

for i in range (0,13):
    df[i] = df[i].str.strip('\n')
    
df['Tempreature'] = 'Mean T Tarragona'
    
df.rename(columns={ 0 : "J", 1 :'F', 2 :'M', 3 :'A', 4 :'My', 5 :'J', 6 :'Jl', 7 :'Ag', 8 :'S', 9 :'O', 10 :'N', 11 :'D', 12 :'ANUAL', }, inplace=True)

dfT = df.iloc[0:1,]

# %%
dfT.head(60)
# Out:
#       J     F      M      A     My      J     Jl     Ag      S      O      N  \
# 30  9.0   9.7   11.9   13.8   17.2   21.2   24.2   24.6   21.5   17.5   12.6
#
#        D  ANUAL       Tempreature
# 30   9.7   16.1  Mean T Tarragona

# %% [markdown]
# ### Temperature for Lleida

# %%
#Import the url

url = "https://es.wikipedia.org/wiki/L%C3%A9rida"
html = urlopen(url)

soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#Get the rows of the data table
rows = soup.find_all('tr')

import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)

df = pd.DataFrame(list_rows)

#Select our interest rows
df = df.iloc[30:40,]

df[0] = df[0].str.strip('[ ] \n')

df = df[0].str.split(',', expand=True)

for i in range (0,13):
    df[i] = df[i].str.strip('\n')
    
df['Tempreature'] = 'Mean T Tarragona'
    
df.rename(columns={ 0 : "J", 1 :'F', 2 :'M', 3 :'A', 4 :'My', 5 :'J', 6 :'Jl', 7 :'Ag', 8 :'S', 9 :'O', 10 :'N', 11 :'D', 12 :'ANUAL', }, inplace=True)

dfL = df.iloc[9:10,]

# %%
dfL.head(60)
# Out:
#       J     F      M      A     My      J     Jl     Ag      S      O     N  \
# 39  5.5   7.7   11.3   13.7   17.9   22.3   25.2   24.9   20.9   15.9   9.7
#
#        D  ANUAL       Tempreature
# 39   5.7   15.0  Mean T Tarragona

# %% [markdown]
# ### Join tables and graph

# %%
dfTOT = pd.concat([dfB,dfT,dfG,dfL], axis=0)
dfTOT = dfTOT.set_index('Tempreature')
dfTOT = dfTOT.drop(columns=["ANUAL"])

dfTOT
# Out:
#                      J      F      M      A     My      J     Jl     Ag  \
# Tempreature
# Mean T Barcelona  11.8   12.4   14.2   15.8   19.3   23.0   25.7   26.1
# Mean T Tarragona   9.0    9.7   11.9   13.8   17.2   21.2   24.2   24.6
# Mean T Girona      7.1    7.9   10.4   12.5   16.3   20.4   23.6   23.4
# Mean T Tarragona   5.5    7.7   11.3   13.7   17.9   22.3   25.2   24.9
#
#                       S      O      N      D
# Tempreature
# Mean T Barcelona   23.0   19.5   14.9   12.3
# Mean T Tarragona   21.5   17.5   12.6    9.7
# Mean T Girona      20.1   16.2   10.9    7.8
# Mean T Tarragona   20.9   15.9    9.7    5.7

# %%
dfTOT2 = dfTOT.T

dfTOT2=dfTOT2.astype(float)

dfTOT2.plot(kind='barh',figsize=(12, 12))

# %% [markdown]
# ## Obtain Barrios (neighborhoods) and sectors of Girona (selected city)
#
# First of all we need to collect our data, "Barrios" and "Sectors" of Girona city. We have the URL with a data table (above) and now we can extract the information.

# %%
#Import the url

url = "https://es.wikipedia.org/wiki/Gerona"
html = urlopen(url)

soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#Get the rows of the data table
rows = soup.find_all('tr')

import re

list_rows = []
for row in rows:
    cells = row.find_all('td')
    str_cells = str(cells)
    clean = re.compile('<.*?>')
    clean2 = (re.sub(clean, '',str_cells))
    list_rows.append(clean2)

df = pd.DataFrame(list_rows)

#Select our interest rows
df1 = df.iloc[50:59,]

#Clean Data
df1[0] = df1[0].str.strip('[ ] \n')
df1 = df1[0].str.split(',', expand=True)
df1[0] = df1[0].str.strip('\n')

new1 = df1[2].copy() 
new2 = df1[3].copy() 
new3 = df1[4].copy() 
new4 = df1[5].copy() 
  
na_string ="None"

df1[1]= df1[1].str.cat(new1, sep =", ", na_rep = na_string) 
df1[1]= df1[1].str.cat(new2, sep =", ", na_rep = na_string) 
df1[1]= df1[1].str.cat(new3, sep =", ", na_rep = na_string) 
df1[1]= df1[1].str.cat(new4, sep =", ", na_rep = na_string) 

col = range(2,6)
df1 = df1.drop(col, axis = 1)

df1[1] = df1[1].str.strip('None, ')
df1[1] = df1[1].str.replace('y ', ', ')

#Display final table
df1
# Out:
# /home/ender/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                 0                                                  1
# 50         Centre                       Barri Vell,  Mercadal , Carm
# 51       Eixample         Sant Narcís,  Eixample Nord , Eixample Sud
# 52            Est  Sant Daniel,  Torre Gironella,  Pedreres,  Fon...
# 53      Mas Xirgu                                          Mas Xirgu
# 54       Montjuïc                                           Montjuïc
# 55           Nord  Pedret,  Pont Major,  Muntanya de Campdorà , P...
# 56           Oest  Sant Ponç,  Fontajau,  Taialà,  Germans Sàbat,...
# 57  Santa Eugènia                Hortes,  Santa Eugènia , Can Gibert
# 58            Sud      Palau,  l'Avellaneda,  Montilivi , la Creueta

# %% [markdown]
# Now the data is clean, we can proceed to export our labels (index)

# %%
#To obtain columns labels

col_labels = soup.find_all('th')

all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)

df2 = pd.DataFrame(all_header)
df2
df3 = df2[0].str.split(',', expand=True)
col = range(0,46)
col2 = range(48,53)
df3 = df3.drop(col, axis = 1)
df3 = df3.drop(col2, axis = 1)
df3[46] = df3[46].str.strip('\n')
df3[47] = df3[47].str.strip('\n')
df3.columns = range(df3.shape[1])

frames = [df3, df1]

df4 = pd.concat(frames)

#Include names and erase all rows with NA

df5 = df4.rename(columns=df4.iloc[0])
df6 = df5.dropna(axis=0, how='any')
df7 = df6.drop(df6.index[0])

df7.rename(columns={" Barrio": "Barrio", ' Sectores':'Sectores' }, inplace=True)
df7.Barrio = df7.Barrio + ', Girona'

df7["Barrio"] = df7["Barrio"].str.replace('Est', 'Sant Daniel')
df7["Barrio"] = df7["Barrio"].str.replace('Nord', 'Pla de Campdorà')
df7["Barrio"] = df7["Barrio"].str.replace('Oest', 'Sant Ponç')
df7["Barrio"] = df7["Barrio"].str.replace('Sud', 'Montilivi')
df7["Barrio"] = df7["Barrio"].str.replace('Eixample', 'Sant Narcís')

df7
# Out:
#                      Barrio                                           Sectores
# 50           Centre, Girona                       Barri Vell,  Mercadal , Carm
# 51      Sant Narcís, Girona         Sant Narcís,  Eixample Nord , Eixample Sud
# 52      Sant Daniel, Girona  Sant Daniel,  Torre Gironella,  Pedreres,  Fon...
# 53        Mas Xirgu, Girona                                          Mas Xirgu
# 54         Montjuïc, Girona                                           Montjuïc
# 55  Pla de Campdorà, Girona  Pedret,  Pont Major,  Muntanya de Campdorà , P...
# 56        Sant Ponç, Girona  Sant Ponç,  Fontajau,  Taialà,  Germans Sàbat,...
# 57    Santa Eugènia, Girona                Hortes,  Santa Eugènia , Can Gibert
# 58        Montilivi, Girona      Palau,  l'Avellaneda,  Montilivi , la Creueta

# %% [markdown]
# ### Now we can extract the coordenates

# %%
#GeocodeFarm, GeoNames, GoogleV3, ny_explorer :: user_agents

#!conda install -c conda-forge geopandas
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode("Girona, Spain")

print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 41.9793006, Longitude = 2.8199439

# %%
from geopy.extra.rate_limiter import RateLimiter

# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# 2- - create location column
df7['location'] = df7['Barrio'].apply(geocode)
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df7['point'] = df7['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# 4 - split point column into latitude, longitude and altitude columns
df7[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df7['point'].tolist(), index=df7.index)
# 5 - drop all columns inecessaries
df7 = df7.drop(["location", "point", "altitude"], axis=1)

dfDA = df7
df7
# Out:
#                      Barrio  \
# 50           Centre, Girona
# 51      Sant Narcís, Girona
# 52      Sant Daniel, Girona
# 53        Mas Xirgu, Girona
# 54         Montjuïc, Girona
# 55  Pla de Campdorà, Girona
# 56        Sant Ponç, Girona
# 57    Santa Eugènia, Girona
# 58        Montilivi, Girona
#
#                                              Sectores   latitude  longitude
# 50                       Barri Vell,  Mercadal , Carm  41.979301   2.819944
# 51         Sant Narcís,  Eixample Nord , Eixample Sud  41.974247   2.811085
# 52  Sant Daniel,  Torre Gironella,  Pedreres,  Fon...  42.002908   2.848043
# 53                                          Mas Xirgu  41.960412   2.804262
# 54                                           Montjuïc  41.994913   2.833146
# 55  Pedret,  Pont Major,  Muntanya de Campdorà , P...  42.025089   2.833761
# 56  Sant Ponç,  Fontajau,  Taialà,  Germans Sàbat,...  41.996909   2.821115
# 57                Hortes,  Santa Eugènia , Can Gibert  41.977527   2.807016
# 58      Palau,  l'Avellaneda,  Montilivi , la Creueta  41.970379   2.831247

# %% [markdown]
# ### And we can see it in a map

# %%
import folium

address = 'Girona, Spain'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Girona are {}, {}.'.format(latitude, longitude))

map_girona = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, Barrio, Sectores in zip(df7['latitude'], df7['longitude'], df7['Barrio'], df7['Sectores']):
    label = '{}, {}'.format(Sectores, Barrio)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_girona)  
    
map_girona
# Out:
# The geograpical coordinate of Girona are 41.9793006, 2.8199439.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Define credentials

CLIENT_ID = 'EMYBPS0CGGFMMDSJVREFWST431MBGFPA4GZ1ZIVJTD4XVGXH' # your Foursquare ID
CLIENT_SECRET = '43TZ4UXGCWY0JVOR3PIK5D3KOO4SRD3ME4A2AYUZHHYD5LVD' # your Foursquare Secret
VERSION = '20200605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: EMYBPS0CGGFMMDSJVREFWST431MBGFPA4GZ1ZIVJTD4XVGXH
# CLIENT_SECRET:43TZ4UXGCWY0JVOR3PIK5D3KOO4SRD3ME4A2AYUZHHYD5LVD

# %%
#Obtain venues of all Neighborhoods
import requests

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Barrio', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ## Look venues for Barrio's

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

girona_venues = getNearbyVenues(names=df7['Barrio'],
                                   latitudes=df7['latitude'],
                                   longitudes=df7['longitude']
                                  )
# Out:
# Centre, Girona
# Sant Narcís, Girona
# Sant Daniel, Girona
# Mas Xirgu, Girona
# Montjuïc, Girona
# Pla de Campdorà, Girona
# Sant Ponç, Girona
# Santa Eugènia, Girona
# Montilivi, Girona

# %%
print(girona_venues.shape)
girona_venues.head()
df7 = girona_venues
df7
# Out:
# (95, 7)
#                Barrio  Neighborhood Latitude  Neighborhood Longitude  \
# 0      Centre, Girona              41.979301                2.819944
# 1      Centre, Girona              41.979301                2.819944
# 2      Centre, Girona              41.979301                2.819944
# 3      Centre, Girona              41.979301                2.819944
# 4      Centre, Girona              41.979301                2.819944
# ..                ...                    ...                     ...
# 90  Montilivi, Girona              41.970379                2.831247
# 91  Montilivi, Girona              41.970379                2.831247
# 92  Montilivi, Girona              41.970379                2.831247
# 93  Montilivi, Girona              41.970379                2.831247
# 94  Montilivi, Girona              41.970379                2.831247
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 0             Pizzeria La Pulcinella       41.978223         2.821999
# 1                    Mercat del Lleó       41.979580         2.822816
# 2                            Llagurt       41.977369         2.821059
# 3                             Indigo       41.978604         2.820871
# 4                 Plaça de Catalunya       41.981658         2.823331
# ..                               ...             ...              ...
# 90                        A 1/2 Camí       41.968896         2.826156
# 91  Can merla (santa coloma farners)       41.969233         2.831031
# 92                       Can Mascort       41.970450         2.836230
# 93                             Solar       41.969338         2.826191
# 94                             Tokio       41.969335         2.826196
#
#          Venue Category
# 0           Pizza Place
# 1                Market
# 2        Ice Cream Shop
# 3     Paella Restaurant
# 4                 Plaza
# ..                  ...
# 90                  Bar
# 91           Restaurant
# 92           Restaurant
# 93              Dog Run
# 94  Japanese Restaurant
#
# [95 rows x 7 columns]

# %% [markdown]
# ### See it in a map

# %%
address = 'Girona, Spain'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Girona are {}, {}.'.format(latitude, longitude))

map_girona = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, Barrio, Sectores in zip(df7['Venue Latitude'], df7['Venue Longitude'], df7['Venue Category'], df7['Venue']):
    label = '{}, {}'.format(Sectores, Barrio)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_girona)  
    
map_girona
# Out:
# The geograpical coordinate of Girona are 41.9793006, 2.8199439.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Analysis of Barrio's venues

# %%
#Neighborhood analisys

# one hot encoding
girona_onehot = pd.get_dummies(girona_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
girona_onehot['Barrio'] = girona_venues['Barrio'] 

# move neighborhood column to the first column
fixed_columns = [girona_onehot.columns[-1]] + list(girona_onehot.columns[:-1])
girona_onehot = girona_onehot[fixed_columns]

girona_grouped = girona_onehot.groupby('Barrio').mean().reset_index()
girona_grouped

#Let's print each neighborhood along with the top 5 most common venues
num_top_venues = 5

for hood in girona_grouped['Barrio']:
    print("----"+hood+"----")
    temp = girona_grouped[girona_grouped['Barrio'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
num_top_venues = 5

#Let's put that into a pandas dataframe
#First, let's write a function to sort the venues in descending order.

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

#Now let's create the new dataframe and display the top 10 venues for each neighborhood.

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Barrio']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Barrio'] = girona_grouped['Barrio']

for ind in np.arange(girona_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(girona_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(9)
# Out:
# ----Centre, Girona----
#                  venue  freq
# 0                Plaza  0.09
# 1       Ice Cream Shop  0.06
# 2        Train Station  0.06
# 3  Japanese Restaurant  0.06
# 4         Burger Joint  0.06
#
#
# ----Mas Xirgu, Girona----
#              venue  freq
# 0       Restaurant  0.12
# 1  Auto Dealership  0.12
# 2      Supermarket  0.12
# 3     Burger Joint  0.12
# 4    Grocery Store  0.12
#
#
# ----Montilivi, Girona----
#                  venue  freq
# 0           Restaurant   0.4
# 1                  Bar   0.2
# 2              Dog Run   0.2
# 3  Japanese Restaurant   0.2
# 4     Tapas Restaurant   0.0
#
#
# ----Montjuïc, Girona----
#              venue  freq
# 0  Bed & Breakfast   0.2
# 1     Soccer Field   0.2
# 2      Snack Place   0.2
# 3           Garden   0.2
# 4       Playground   0.2
#
#
# ----Pla de Campdorà, Girona----
#                  venue  freq
# 0              Dog Run   0.5
# 1           Restaurant   0.5
# 2   Athletics & Sports   0.0
# 3  Japanese Restaurant   0.0
# 4               Market   0.0
#
#
# ----Sant Daniel, Girona----
#                  venue  freq
# 0           Restaurant   1.0
# 1   Athletics & Sports   0.0
# 2                Plaza   0.0
# 3  Japanese Restaurant   0.0
# 4               Market   0.0
#
#
# ----Sant Narcís, Girona----
#                 venue  freq
# 0         Supermarket  0.12
# 1                Café  0.12
# 2  Athletics & Sports  0.06
# 3    Department Store  0.06
# 4         Snack Place  0.06
#
#
# ----Sant Ponç, Girona----
#                       venue  freq
# 0                     Hotel  0.27
# 1                  Gym Pool  0.09
# 2               Supermarket  0.09
# 3  Mediterranean Restaurant  0.09
# 4              Burger Joint  0.09
#
#
# ----Santa Eugènia, Girona----
#                       venue  freq
# 0  Mediterranean Restaurant  0.13
# 1                      Café  0.13
# 2               Supermarket  0.13
# 3            Farmers Market  0.07
# 4                 Gift Shop  0.07
#                     Barrio 1st Most Common Venue 2nd Most Common Venue  \
# 0           Centre, Girona                 Plaza   Japanese Restaurant
# 1        Mas Xirgu, Girona                  Café         Shopping Mall
# 2        Montilivi, Girona            Restaurant                   Bar
# 3         Montjuïc, Girona            Playground                Garden
# 4  Pla de Campdorà, Girona            Restaurant               Dog Run
# 5      Sant Daniel, Girona            Restaurant              Wine Bar
# 6      Sant Narcís, Girona           Supermarket                  Café
# 7        Sant Ponç, Girona                 Hotel              Gym Pool
# 8    Santa Eugènia, Girona                  Café           Supermarket
#
#       3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0              Burger Joint        Ice Cream Shop         Train Station
# 1         Electronics Store          Burger Joint            Restaurant
# 2       Japanese Restaurant               Dog Run              Wine Bar
# 3              Soccer Field           Snack Place       Bed & Breakfast
# 4                  Wine Bar      Department Store         Grocery Store
# 5          Department Store         Grocery Store             Gift Shop
# 6                     Hotel                 Plaza      Basketball Court
# 7               Supermarket   Fried Chicken Joint        Sandwich Place
# 8  Mediterranean Restaurant                   Bar      Basketball Court
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0              Wine Bar                   Gym                Market
# 1         Grocery Store           Supermarket       Auto Dealership
# 2          Dessert Shop             Gift Shop             Gastropub
# 3      Department Store             Gift Shop             Gastropub
# 4             Gift Shop             Gastropub                Garden
# 5             Gastropub                Garden   Fried Chicken Joint
# 6             Cafeteria      Department Store        Farmers Market
# 7            Restaurant          Burger Joint                 Plaza
# 8            Smoke Shop             Cafeteria                 Plaza
#
#       9th Most Common Venue 10th Most Common Venue
# 0        Italian Restaurant              Gastropub
# 1          Basketball Court                Dog Run
# 2                    Garden    Fried Chicken Joint
# 3       Fried Chicken Joint                   Food
# 4       Fried Chicken Joint                   Food
# 5                      Food         Farmers Market
# 6                      Food              Gift Shop
# 7  Mediterranean Restaurant       Department Store
# 8                 Gift Shop            Pizza Place

# %% [markdown]
# ### Segment in clusters (by venues

# %%
from sklearn.cluster import KMeans
#Cluster Neighborhoods
#Run k-means to cluster the neighborhood into 5 clusters.

# set number of clusters
kclusters = 3

girona_grouped_clustering = girona_grouped.drop('Barrio', 1)

# run k-means clustering

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(girona_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

girona_merged = df7

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
girona_merged = girona_merged.join(neighborhoods_venues_sorted.set_index('Barrio'), on='Barrio')

girona_merged['Cluster Labels'] = girona_merged['Cluster Labels'].fillna(0).astype(np.int64)
#toronto_merged['Cluster Labels'] = toronto_merged['Cluster Labels'].astype("int")

girona_merged.head(10) # check the last columns!
# Out:
#            Barrio  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Centre, Girona              41.979301                2.819944
# 1  Centre, Girona              41.979301                2.819944
# 2  Centre, Girona              41.979301                2.819944
# 3  Centre, Girona              41.979301                2.819944
# 4  Centre, Girona              41.979301                2.819944
# 5  Centre, Girona              41.979301                2.819944
# 6  Centre, Girona              41.979301                2.819944
# 7  Centre, Girona              41.979301                2.819944
# 8  Centre, Girona              41.979301                2.819944
# 9  Centre, Girona              41.979301                2.819944
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0  Pizzeria La Pulcinella       41.978223         2.821999
# 1         Mercat del Lleó       41.979580         2.822816
# 2                 Llagurt       41.977369         2.821059
# 3                  Indigo       41.978604         2.820871
# 4      Plaça de Catalunya       41.981658         2.823331
# 5          Escondido Cafè       41.977773         2.822520
# 6                   König       41.977193         2.821080
# 7                    Umai       41.983094         2.821719
# 8             La Gioconda       41.981722         2.823458
# 9         Hotel Carlemany       41.978615         2.820819
#
#         Venue Category  Cluster Labels 1st Most Common Venue  \
# 0          Pizza Place               1                 Plaza
# 1               Market               1                 Plaza
# 2       Ice Cream Shop               1                 Plaza
# 3    Paella Restaurant               1                 Plaza
# 4                Plaza               1                 Plaza
# 5   Mexican Restaurant               1                 Plaza
# 6         Burger Joint               1                 Plaza
# 7  Japanese Restaurant               1                 Plaza
# 8       Ice Cream Shop               1                 Plaza
# 9                Hotel               1                 Plaza
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 1   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 2   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 3   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 4   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 5   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 6   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 7   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 8   Japanese Restaurant          Burger Joint        Ice Cream Shop
# 9   Japanese Restaurant          Burger Joint        Ice Cream Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Train Station              Wine Bar                   Gym
# 1         Train Station              Wine Bar                   Gym
# 2         Train Station              Wine Bar                   Gym
# 3         Train Station              Wine Bar                   Gym
# 4         Train Station              Wine Bar                   Gym
# 5         Train Station              Wine Bar                   Gym
# 6         Train Station              Wine Bar                   Gym
# 7         Train Station              Wine Bar                   Gym
# 8         Train Station              Wine Bar                   Gym
# 9         Train Station              Wine Bar                   Gym
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                Market    Italian Restaurant              Gastropub
# 1                Market    Italian Restaurant              Gastropub
# 2                Market    Italian Restaurant              Gastropub
# 3                Market    Italian Restaurant              Gastropub
# 4                Market    Italian Restaurant              Gastropub
# 5                Market    Italian Restaurant              Gastropub
# 6                Market    Italian Restaurant              Gastropub
# 7                Market    Italian Restaurant              Gastropub
# 8                Market    Italian Restaurant              Gastropub
# 9                Market    Italian Restaurant              Gastropub

# %% [markdown]
# ### Apply cluster in a map

# %%
#Mapping

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(girona_merged['Neighborhood Latitude'], girona_merged['Neighborhood Longitude'], girona_merged['Barrio'], girona_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### We can select only cluster num 1

# %%
dfclust1 = girona_merged.loc[girona_merged['Cluster Labels'] == 1]

dfclust1.head(5)
# Out:
#            Barrio  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Centre, Girona              41.979301                2.819944
# 1  Centre, Girona              41.979301                2.819944
# 2  Centre, Girona              41.979301                2.819944
# 3  Centre, Girona              41.979301                2.819944
# 4  Centre, Girona              41.979301                2.819944
#
#                     Venue  Venue Latitude  Venue Longitude     Venue Category  \
# 0  Pizzeria La Pulcinella       41.978223         2.821999        Pizza Place
# 1         Mercat del Lleó       41.979580         2.822816             Market
# 2                 Llagurt       41.977369         2.821059     Ice Cream Shop
# 3                  Indigo       41.978604         2.820871  Paella Restaurant
# 4      Plaça de Catalunya       41.981658         2.823331              Plaza
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1                 Plaza   Japanese Restaurant
# 1               1                 Plaza   Japanese Restaurant
# 2               1                 Plaza   Japanese Restaurant
# 3               1                 Plaza   Japanese Restaurant
# 4               1                 Plaza   Japanese Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0          Burger Joint        Ice Cream Shop         Train Station
# 1          Burger Joint        Ice Cream Shop         Train Station
# 2          Burger Joint        Ice Cream Shop         Train Station
# 3          Burger Joint        Ice Cream Shop         Train Station
# 4          Burger Joint        Ice Cream Shop         Train Station
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0              Wine Bar                   Gym                Market
# 1              Wine Bar                   Gym                Market
# 2              Wine Bar                   Gym                Market
# 3              Wine Bar                   Gym                Market
# 4              Wine Bar                   Gym                Market
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Italian Restaurant              Gastropub
# 1    Italian Restaurant              Gastropub
# 2    Italian Restaurant              Gastropub
# 3    Italian Restaurant              Gastropub
# 4    Italian Restaurant              Gastropub

# %% [markdown]
# ### First venue
#
# plot counts of first common venue

# %%
nearby_venues0 = dfclust1.groupby(["1st Most Common Venue"]).size().reset_index(name='count')

nearby_venues0 = nearby_venues0.set_index('1st Most Common Venue')
nearby_venues0 = nearby_venues0.sort_values(by=['count'])

nearby_venues0

# step 1: get the data

# step 2: plot data
nearby_venues0.plot(kind='barh', figsize=(12, 12), color='steelblue')

plt.xlabel('Categories') # add to x-label to the plot
plt.ylabel('Counts') # add y-label to the plot
plt.title('1st Most Common Venue') # add title to the plot

plt.show()

# %% [markdown]
# ### Second
#
# plot counts of second common venue

# %%
nearby_venues0 = dfclust1.groupby(["2nd Most Common Venue"]).size().reset_index(name='count')

nearby_venues0 = nearby_venues0.set_index('2nd Most Common Venue')
nearby_venues0 = nearby_venues0.sort_values(by=['count'])

nearby_venues0

# step 1: get the data

# step 2: plot data
nearby_venues0.plot(kind='barh', figsize=(12, 12), color='steelblue')

plt.xlabel('Categories') # add to x-label to the plot
plt.ylabel('Counts') # add y-label to the plot
plt.title('2nd Most Common Venue') # add title to the plot

plt.show()

# %% [markdown]
# ### Third
#
# plot counts of first common venue

# %%
nearby_venues0 = dfclust1.groupby(["3rd Most Common Venue"]).size().reset_index(name='count')

nearby_venues0 = nearby_venues0.set_index('3rd Most Common Venue')
nearby_venues0 = nearby_venues0.sort_values(by=['count'])

nearby_venues0

# step 1: get the data

# step 2: plot data
nearby_venues0.plot(kind='barh', figsize=(12, 12), color='steelblue')

plt.xlabel('Categories') # add to x-label to the plot
plt.ylabel('Counts') # add y-label to the plot
plt.title('3rd Most Common Venue') # add title to the plot

plt.show()

# %% [markdown]
# ### And then plot to see the most common venues

# %%
nearby_venues = dfclust1.groupby(["Venue Category"]).size().reset_index(name='count')

nearby_venues = nearby_venues.set_index('Venue Category')
nearby_venues = nearby_venues.sort_values(by=['count'])

nearby_venues

# step 1: get the data

# step 2: plot data
nearby_venues.plot(kind='barh', figsize=(12, 12), color='steelblue')

plt.xlabel('Categories') # add to x-label to the plot
plt.ylabel('Counts') # add y-label to the plot
plt.title('All Venues') # add title to the plot

plt.show()
